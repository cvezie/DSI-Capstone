# %% [markdown]
# # Data Cleaning
#
# ####  Goals
# * Split into numerical and categorical
# * Assess null values in each category.
#
#
# #### Output
# * Cleaned data including initial stats DataFrame.

# %%
cd ..
# Out:
# /home/jovyan/dsi/CAPSTONE

# %%
# %run __init__.py

# %%
# %matplotlib inline

# %% [markdown]
# ### 1. Load `commute_df_with_nulls`

# %%
commute_df_with_nulls = pd.read_pickle('./data/commute_df_anon.pkl')

# %% [markdown]
# ### 2. Check `.dtypes`
# * Make sure categorical columns are labeled as such.
# * Make sure numerical columns are labeled as floats.

# %%
for col in commute_df_with_nulls.columns:
    if commute_df_with_nulls[col].dtype == object:
        commute_df_with_nulls[col] = commute_df_with_nulls[col].astype('category')

# %%
commute_dtypes_df = pd.DataFrame([commute_df_with_nulls.dtypes],
                                 index=['column_dtypes']).T
commute_dtypes_df
# Out:
#                                                    column_dtypes
# Survey_Cycle                                            category
# response_rate                                            float64
# num_employees                                            float64
# VMT_employee                                             float64
# goal_vmt                                                 float64
# total_vmt                                                float64
# total_goal_vmt                                          category
# ndat_rate                                                float64
# goal_ndat_rate_worksite_only                             float64
# total_goal_ndat_trips                                   category
# total_annual_ghg_emissions_metric_tons_C02e              float64
# daily_roundtrip_ghg_per_employee_pounds                  float64
# ghg_for_agg_pounds                                      category
# total_weekly_trips                                       float64
# weekly_drive_alone                                       float64
# weekly_carpool                                           float64
# weekly_vanpool                                           float64
# weekly_1_motorcycle                                      float64
# weekly_2_motorcycle                                      float64
# weekly_bus                                               float64
# weekly_train_lightrail_streetcar                         float64
# weekly_bike                                              float64
# weekly_walk                                              float64
# weekly_telework                                          float64
# weekly_cww                                               float64
# weekly_overnight_business                                float64
# weekly_did_not_work                                      float64
# weekly_ferry_walk_on                                     float64
# weekly_ferry_car_bus_van                                 float64
# weekly_other                                             float64
# ...                                                          ...
# offers_uncovered_racks_for_walkers_bicyclists           category
# employees_able_to_set_aside_pretax_income_for_t...      category
# total_number_parking_spaces_reserved_for_employees      category
# number_reserved_HOV_parking_spaces                      category
# number_shared_parking_spaces                            category
# offers_remove_work_options                              category
# offers_flexible_work_hours                              category
# offers_compressed_work_week_scheduling                  category
# offers_free_ride_home_in_emergency                      category
# offers_carshare_discounts                               category
# offers_lyft_uber_taxi_discounts                         category
# offers_bikeshare_discounts                              category
# employer_provided_shuttle_available                     category
# internal_circulator_available                           category
# employer_provided_cars_for_offsite_business_app...      category
# offers_company_provided_bikes                           category
# offers_internal_carpool_ride_matching                   category
# offers_rideshare_online_3rdparty_ride_matching          category
# additional_transportation_benefits                      category
# yearly_cost_promoting_CTR_and_overhead                   float64
# yearly_cost_meeting_program_requirements                 float64
# yearly_cost_of_financial_incentives_subsidies_t...       float64
# yearly_cost_of_facilities                                float64
# yearly_cost_other                                        float64
# explanation_of_other_cost                               category
# employer_applied_for_state_tax_credits_for_supp...      category
# What are your worksite's transportation program...      category
# What are your worksite's transportation program...      category
# What are your worksite's transportation program...      category
# UUID                                                    category
#
# [106 rows x 1 columns]

# %% [markdown]
# #### Category Columns

# %%
commute_dtypes_df.loc[commute_dtypes_df['column_dtypes'] == 'category'].T.columns
# Out:
# Index(['Survey_Cycle', 'total_goal_vmt', 'total_goal_ndat_trips',
#        'ghg_for_agg_pounds', 'alone_share', 'carpool_share', 'van_share',
#        'motorcycle_share', 'bus_share', 'train_share', 'bike_share',
#        'walk_share', 'tele_share', 'cww_share', 'used_ferry_share',
#        'boarded_ferry_share', 'other_share',
#        'is_worksite_moving_in_six_months', 'reason_for_moving',
#        'worksite_located_in_building_with_TMP', 'familiar_with_TMP',
#        'visible_ETC_info', 'provides_commute_info_via_digital_visible_display',
#        'time_last_distributed_commute_info',
#        'Do you distribute transportation program information to new hires via a new employee orientation/hiring packet/new hire online modules?',
#        'bus_streetcar_within_3_blocks', 'light_rail_train_within_3_blocks',
#        'bike_ped_trail_within_3_blocks', 'sidewalks',
#        'ORCA_business_passport_offfered',
#        'offers_mass_transit_benefit_subsidy_other_than_ORCA_business',
#        'offers_vanshare_carpool_subsidy',
#        'offers_parking_subsidy_for_vanshares-carpools',
#        'offers_parking_subsidy_for_drive_alone', 'offers_bike_subsidy',
#        'offers_other_non-specific_transportation_subsidy',
#        'Please enter any details about subsidies',
#        'offers_showers_for_walkers_bicyclists',
#        'offers_lockers_for_walkers_bicyclists',
#        'offers_locked_bike_room_for_walkers_bicyclists',
#        'offers_covered_racks_for_walkers_bicyclists',
#        'offers_uncovered_racks_for_walkers_bicyclists',
#        'employees_able_to_set_aside_pretax_income_for_transit_vanpool_cost',
#        'total_number_parking_spaces_reserved_for_employees',
#        'number_reserved_HOV_parking_spaces', 'number_shared_parking_spaces',
#        'offers_remove_work_options', 'offers_flexible_work_hours',
#        'offers_compressed_work_week_scheduling',
#        'offers_free_ride_home_in_emergency', 'offers_carshare_discounts',
#        'offers_lyft_uber_taxi_discounts', 'offers_bikeshare_discounts',
#        'employer_provided_shuttle_available', 'internal_circulator_available',
#        'employer_provided_cars_for_offsite_business_appointments_available',
#        'offers_company_provided_bikes',
#        'offers_internal_carpool_ride_matching',
#        'offers_rideshare_online_3rdparty_ride_matching',
#        'additional_transportation_benefits', 'explanation_of_other_cost',
#        'employer_applied_for_state_tax_credits_for_supporting_employee_commute_alternatives',
#        'What are your worksite's transportation program priorities for the next 6 months?1',
#        'What are your worksite's transportation program priorities for the next 6 months?2',
#        'What are your worksite's transportation program priorities for the next 6 months?3',
#        'UUID'],
#       dtype='object')

# %% [markdown]
# #### Float columns

# %%
commute_dtypes_df.loc[commute_dtypes_df['column_dtypes'] == np.float].T.columns
# Out:
# Index(['response_rate', 'num_employees', 'VMT_employee', 'goal_vmt',
#        'total_vmt', 'ndat_rate', 'goal_ndat_rate_worksite_only',
#        'total_annual_ghg_emissions_metric_tons_C02e',
#        'daily_roundtrip_ghg_per_employee_pounds', 'total_weekly_trips',
#        'weekly_drive_alone', 'weekly_carpool', 'weekly_vanpool',
#        'weekly_1_motorcycle', 'weekly_2_motorcycle', 'weekly_bus',
#        'weekly_train_lightrail_streetcar', 'weekly_bike', 'weekly_walk',
#        'weekly_telework', 'weekly_cww', 'weekly_overnight_business',
#        'weekly_did_not_work', 'weekly_ferry_walk_on',
#        'weekly_ferry_car_bus_van', 'weekly_other', 'Worksite_2017_DAR_goal',
#        'num_employees_at_worksite',
#        'How many employees arrive at your worksite between 6 and 9 AM? (#)',
#        'number_employees_using_ORCA_business_passport',
#        'number_employees_using_mass_transit_subsidy',
#        'number_employees_using_vanshare_carpool_subsidy',
#        'number_employees_drive_alone_using_parking_subsidy',
#        'number_employees_using_bike_subsidy',
#        'number_employees_using_other_transportation_subsidy',
#        'yearly_cost_promoting_CTR_and_overhead',
#        'yearly_cost_meeting_program_requirements',
#        'yearly_cost_of_financial_incentives_subsidies_to_employees',
#        'yearly_cost_of_facilities', 'yearly_cost_other'],
#       dtype='object')

# %% [markdown]
# #### Object Columns

# %%
commute_dtypes_df.loc[commute_dtypes_df['column_dtypes'] == 'object'].T.columns
# Out:
# Index([], dtype='object')

# %% [markdown]
# #### Identifying wrongly categorized columns and reassigning into the appropriate dtype.

# %%
# columns with percentage values. remove the %, change to type float and divide by 100
percentage_columns_to_make_numeric = ['alone_share',
                                      'carpool_share',
                                      'van_share',
                                      'motorcycle_share',
                                      'bus_share',
                                      'train_share',
                                      'bike_share',
                                      'walk_share',
                                      'tele_share',
                                      'cww_share',
                                      'used_ferry_share',
                                      'boarded_ferry_share',
                                      'other_share']

# %%
# reclassifying percentage columns as floats.
for col in percentage_columns_to_make_numeric:
    commute_df_with_nulls[col] = commute_df_with_nulls[col].str.replace('\%', '').astype(np.float64)/100

# %%
# some numbers contain ',', remove these and change to float
columns_to_make_numeric_one = ['total_goal_vmt', 
                               'total_goal_ndat_trips',
                               'ghg_for_agg_pounds'
                              ]
                               
# contains strings that need to be replaced.                               
columns_to_make_numeric_two = ['total_number_parking_spaces_reserved_for_employees',
                               'number_reserved_HOV_parking_spaces', 
                               'number_shared_parking_spaces'
                              ]

# %%
for col in columns_to_make_numeric_one:
    commute_df_with_nulls[col] = commute_df_with_nulls[col].str.replace(',', '').astype(np.float64)

# %%
replacements_parking_space = {'138 rentable space': '138',
                              '141 (staff and customers)': '141',
                              '173 (nearby at Jack MacDonald Building)': '173',
                              '33, per our lease': '33',
                              '453 - including accessible, motorcycle, HOV, Hybrid, etc.': '453',
                              "6 for VP's and CEO only": '6',
                              '802 regular and 35 motorcycle stalls located onsite, approximately 550 regular stalls off-site.  ': '1387',
                              'Controlled by landlord': '-1',
                              'No': '0',
                              'None': '0',
                              'Unknown': '-1',
                              'Unknown ': '-1',
                              'Unknown, handled by Republic parking': '-1',
                              'no': '0',
                              'one': '1',
                              'unknown': '-1'
                             }

# %%
replacements_HOV = {
   'unknown': '-1',
   'available at Macdonald': '0',
   'available at MacDonald lot': '0',
   'Unknown': '-1',
   'Unknown ': '-1',
   '5 Vanpool and carpools recieve priority': '5',
   'no': '0',
   '25 premium spaces reserved for Vanpool and carpools receive priority for onsite parking': '25',
   '8 (of the 141 above)': '8',
   'unknow': '-1',
   'As needed': '-1',
   'approx. 6': '6',
   'Discounted & reserved/priority parking is available for carpools & vanpools': '-1',
   'Unknown - It is a public parking garage managed by Republic Parking': '-1',
   'None': '0',
   'Uknown': '-1',
   'unknown ': '-1',
   'none': '0',
   'available at Mac Donald lot': '0',
   '3 Vanpool and carpools given priority': '3',
   'Landlord provided spaces': '-1',
   'Controlled by landlord': '-1' 
}

# %%
commute_df_with_nulls['number_shared_parking_spaces'].unique()
# Out:
# [unknown, 0, 1, NaN, Unknown, ..., 32 visitor stalls, 5, Yes, 164, Unknown]
# Length: 79
# Categories (78, object): [unknown, 0, 1, Unknown, ..., 5, Yes, 164, Unknown]

# %%
replacements_shared_parking = {
   'Unknown': '-1',
   'unknown ': '-1',
   'unknown': '-1',
   'Unknown ': '-1',
   'Over 700': '701',
   'Yes': '-1',
   '5 floors of parking stalls in building garage': '-1',
   '9 visitor stalls': '9',
   'UNKNOW': '-1',
   'unknown (neighborhood paid lots are reimbursed)': '-1',
   'none': '0',
   'Yes availble to public, approx. 600': '600',
   'Off street parking available 2 block radius of building': '0',
   'Controlled by landlord': '-1',
   '32 visitor stalls': '32',
   '500+ (on the opposite side of E. Marginal Way)': '500',
   '10/12/2017': '-1',
   'Street Parking ': '0', 
   "703 (in building's garage, $353/mo., no subsidy provided)": '703', 
   'multiple metered street spaces': '0', 
   '12 (customers only--no staff)': '0', # these spaces are not for employees
   'Unknown - It is a public parking garage managed by Republic Parking': '-1',
   'All': '0', # I looked up the value in total number parking spaces for these columns to get this value.
   'unknow': '-1',
   '835 onsite for patients/families/visitors.  Staff may not use.': '0', # these spaces are not for employees.  
   'more': '-1', 
   'street parking': '0', 
}

# %%
# TOTAL RESERVED PARKING REASSIGNMENT ---> FLOAT

commute_df_with_nulls['total_number_parking_spaces_reserved_for_employees'] = commute_df_with_nulls['total_number_parking_spaces_reserved_for_employees'].apply(lambda x: replacements_parking_space[x] if x in replacements_parking_space else x).astype(np.float)

# %%
# HOV PARKING REASSIGNMENT ---> FLOAT

commute_df_with_nulls['number_reserved_HOV_parking_spaces'] = commute_df_with_nulls['number_reserved_HOV_parking_spaces'].apply(lambda x: replacements_HOV[x] if x in replacements_HOV else x).astype(np.float)

# %%
commute_df_with_nulls.loc[commute_df_with_nulls['number_shared_parking_spaces'] == 'All']['total_number_parking_spaces_reserved_for_employees']
# Out:
# 622    0.0
# 623    0.0
# 624    0.0
# 625    0.0
# 626    0.0
# Name: total_number_parking_spaces_reserved_for_employees, dtype: float64

# %%
# SHARED PARKING REASSIGNMENT ---> FLOAT

commute_df_with_nulls['number_shared_parking_spaces'] = commute_df_with_nulls['number_shared_parking_spaces'].apply(lambda x: replacements_shared_parking[x] if x in replacements_shared_parking else x).astype(np.float)

# %% [markdown]
# #### Rechecking dtypes

# %%
commute_dtypes_df = pd.DataFrame([commute_df_with_nulls.dtypes],
                                 index=['column_dtypes']).T
commute_dtypes_df
# Out:
#                                                    column_dtypes
# Survey_Cycle                                            category
# response_rate                                            float64
# num_employees                                            float64
# VMT_employee                                             float64
# goal_vmt                                                 float64
# total_vmt                                                float64
# total_goal_vmt                                           float64
# ndat_rate                                                float64
# goal_ndat_rate_worksite_only                             float64
# total_goal_ndat_trips                                    float64
# total_annual_ghg_emissions_metric_tons_C02e              float64
# daily_roundtrip_ghg_per_employee_pounds                  float64
# ghg_for_agg_pounds                                       float64
# total_weekly_trips                                       float64
# weekly_drive_alone                                       float64
# weekly_carpool                                           float64
# weekly_vanpool                                           float64
# weekly_1_motorcycle                                      float64
# weekly_2_motorcycle                                      float64
# weekly_bus                                               float64
# weekly_train_lightrail_streetcar                         float64
# weekly_bike                                              float64
# weekly_walk                                              float64
# weekly_telework                                          float64
# weekly_cww                                               float64
# weekly_overnight_business                                float64
# weekly_did_not_work                                      float64
# weekly_ferry_walk_on                                     float64
# weekly_ferry_car_bus_van                                 float64
# weekly_other                                             float64
# ...                                                          ...
# offers_uncovered_racks_for_walkers_bicyclists           category
# employees_able_to_set_aside_pretax_income_for_t...      category
# total_number_parking_spaces_reserved_for_employees       float64
# number_reserved_HOV_parking_spaces                       float64
# number_shared_parking_spaces                             float64
# offers_remove_work_options                              category
# offers_flexible_work_hours                              category
# offers_compressed_work_week_scheduling                  category
# offers_free_ride_home_in_emergency                      category
# offers_carshare_discounts                               category
# offers_lyft_uber_taxi_discounts                         category
# offers_bikeshare_discounts                              category
# employer_provided_shuttle_available                     category
# internal_circulator_available                           category
# employer_provided_cars_for_offsite_business_app...      category
# offers_company_provided_bikes                           category
# offers_internal_carpool_ride_matching                   category
# offers_rideshare_online_3rdparty_ride_matching          category
# additional_transportation_benefits                      category
# yearly_cost_promoting_CTR_and_overhead                   float64
# yearly_cost_meeting_program_requirements                 float64
# yearly_cost_of_financial_incentives_subsidies_t...       float64
# yearly_cost_of_facilities                                float64
# yearly_cost_other                                        float64
# explanation_of_other_cost                               category
# employer_applied_for_state_tax_credits_for_supp...      category
# What are your worksite's transportation program...      category
# What are your worksite's transportation program...      category
# What are your worksite's transportation program...      category
# UUID                                                    category
#
# [106 rows x 1 columns]

# %% [markdown]
# ## 2. Identify categorical and numerical columns in separate lists
#
# #### Category columns

# %%
categorical_columns = list(commute_dtypes_df.loc[commute_dtypes_df['column_dtypes'] == 'category'].T.columns)

# %% [markdown]
# #### Float columns

# %%
numerical_columns = list(commute_dtypes_df.loc[commute_dtypes_df['column_dtypes'] == np.float].T.columns)

# %% [markdown]
# ## 3. `.describe()` and initial stats

# %%
commute_stats_df = commute_df_with_nulls.describe().T
commute_stats_df
# Out:
#                                                      count           mean  \
# response_rate                                       1042.0      76.483397
# num_employees                                       1042.0     619.629559
# VMT_employee                                        1042.0       6.553071
# goal_vmt                                            1042.0       1.020345
# total_vmt                                           1042.0    2299.072841
# total_goal_vmt                                      1042.0     398.443570
# ndat_rate                                           1042.0      61.316219
# goal_ndat_rate_worksite_only                        1042.0      10.709021
# total_goal_ndat_trips                               1042.0     216.945393
# total_annual_ghg_emissions_metric_tons_C02e         1042.0     811.827284
# daily_roundtrip_ghg_per_employee_pounds             1042.0      12.753071
# ghg_for_agg_pounds                                  1042.0    4478.252601
# total_weekly_trips                                  1042.0    1744.908829
# weekly_drive_alone                                  1042.0     634.729367
# weekly_carpool                                      1042.0     171.198656
# weekly_vanpool                                      1042.0      28.187140
# weekly_1_motorcycle                                 1042.0      11.404990
# weekly_2_motorcycle                                 1042.0       0.820537
# weekly_bus                                          1042.0     567.067179
# weekly_train_lightrail_streetcar                    1042.0      68.567179
# weekly_bike                                         1042.0      61.037428
# weekly_walk                                         1042.0      75.453935
# weekly_telework                                     1042.0      66.624760
# weekly_cww                                          1042.0       6.673704
# weekly_overnight_business                           1042.0       8.094050
# weekly_did_not_work                                 1042.0      43.527831
# weekly_ferry_walk_on                                1042.0      23.104607
# weekly_ferry_car_bus_van                            1042.0       6.663148
# weekly_other                                        1042.0      23.373321
# alone_share                                         1042.0       0.379931
# carpool_share                                       1042.0       0.095100
# van_share                                           1042.0       0.013008
# motorcycle_share                                    1042.0       0.007439
# bus_share                                           1042.0       0.325146
# train_share                                         1042.0       0.041824
# bike_share                                          1042.0       0.025955
# walk_share                                          1042.0       0.043740
# tele_share                                          1042.0       0.033003
# cww_share                                           1042.0       0.003264
# used_ferry_share                                    1042.0       0.006599
# boarded_ferry_share                                 1042.0       0.012171
# other_share                                         1042.0       0.012778
# Worksite_2017_DAR_goal                              1042.0      36.357006
# num_employees_at_worksite                           1042.0     690.073896
# How many employees arrive at your worksite betw...  1042.0     520.310940
# number_employees_using_ORCA_business_passport        995.0     434.015075
# number_employees_using_mass_transit_subsidy          995.0      62.833166
# number_employees_using_vanshare_carpool_subsidy      995.0      37.458291
# number_employees_drive_alone_using_parking_subsidy   995.0      38.470352
# number_employees_using_bike_subsidy                  995.0      10.132663
# number_employees_using_other_transportation_sub...   995.0      38.257286
# total_number_parking_spaces_reserved_for_employees  1042.0     148.588292
# number_reserved_HOV_parking_spaces                  1042.0       9.991363
# number_shared_parking_spaces                        1042.0     133.107486
# yearly_cost_promoting_CTR_and_overhead               971.0   51800.359423
# yearly_cost_meeting_program_requirements             971.0   84410.454171
# yearly_cost_of_financial_incentives_subsidies_t...   971.0  469635.505664
# yearly_cost_of_facilities                            971.0    2730.348095
# yearly_cost_other                                    971.0  100697.122554
#
#                                                              std      min  \
# response_rate                                       1.186358e+01   16.400
# num_employees                                       1.738325e+03   56.000
# VMT_employee                                        3.930913e+00    0.900
# goal_vmt                                            2.559574e+00    0.000
# total_vmt                                           5.193564e+03   82.800
# total_goal_vmt                                      2.872308e+03    0.000
# ndat_rate                                           2.119511e+01    7.900
# goal_ndat_rate_worksite_only                        2.511491e+01    0.000
# total_goal_ndat_trips                               1.740630e+03    0.000
# total_annual_ghg_emissions_metric_tons_C02e         1.743169e+03   21.200
# daily_roundtrip_ghg_per_employee_pounds             7.654836e+00    1.700
# ghg_for_agg_pounds                                  1.021849e+04  153.640
# total_weekly_trips                                  4.314941e+03  142.000
# weekly_drive_alone                                  1.512218e+03   19.000
# weekly_carpool                                      4.275925e+02    4.000
# weekly_vanpool                                      8.230205e+01    0.000
# weekly_1_motorcycle                                 2.688344e+01    0.000
# weekly_2_motorcycle                                 2.472411e+00    0.000
# weekly_bus                                          1.612154e+03    0.000
# weekly_train_lightrail_streetcar                    1.398089e+02    0.000
# weekly_bike                                         3.032103e+02    0.000
# weekly_walk                                         1.919455e+02    0.000
# weekly_telework                                     2.630869e+02    0.000
# weekly_cww                                          2.936293e+01    0.000
# weekly_overnight_business                           1.506109e+01    0.000
# weekly_did_not_work                                 9.544258e+01    0.000
# weekly_ferry_walk_on                                5.219252e+01    0.000
# weekly_ferry_car_bus_van                            2.290193e+01    0.000
# weekly_other                                        5.114087e+01    0.000
# alone_share                                         2.097788e-01    0.040
# carpool_share                                       4.456424e-02    0.006
# van_share                                           2.739810e-02    0.000
# motorcycle_share                                    9.558756e-03    0.000
# bus_share                                           1.958187e-01    0.000
# train_share                                         4.205033e-02    0.000
# bike_share                                          2.607493e-02    0.000
# walk_share                                          3.394811e-02    0.000
# tele_share                                          5.210207e-02    0.000
# cww_share                                           6.859618e-03    0.000
# used_ferry_share                                    1.117049e-02    0.000
# boarded_ferry_share                                 1.786398e-02    0.000
# other_share                                         1.031355e-02    0.000
# Worksite_2017_DAR_goal                              2.029379e+01    0.000
# num_employees_at_worksite                           2.006764e+03    5.000
# How many employees arrive at your worksite betw...  1.527593e+03    5.000
# number_employees_using_ORCA_business_passport       2.777726e+03    0.000
# number_employees_using_mass_transit_subsidy         2.015595e+02    0.000
# number_employees_using_vanshare_carpool_subsidy     2.028805e+02    0.000
# number_employees_drive_alone_using_parking_subsidy  9.278286e+01    0.000
# number_employees_using_bike_subsidy                 5.572582e+01    0.000
# number_employees_using_other_transportation_sub...  2.792564e+02    0.000
# total_number_parking_spaces_reserved_for_employees  5.943407e+02   -1.000
# number_reserved_HOV_parking_spaces                  4.675136e+01   -1.000
# number_shared_parking_spaces                        7.224711e+02   -1.000
# yearly_cost_promoting_CTR_and_overhead              3.413862e+05    0.000
# yearly_cost_meeting_program_requirements            6.367192e+05    0.000
# yearly_cost_of_financial_incentives_subsidies_t...  1.406933e+06    0.000
# yearly_cost_of_facilities                           1.291493e+04    0.000
# yearly_cost_other                                   4.658899e+05    0.000
#
#                                                             25%         50%  \
# response_rate                                         71.325000    76.10000
# num_employees                                        185.250000   310.50000
# VMT_employee                                           3.500000     5.60000
# goal_vmt                                               0.000000     0.00000
# total_vmt                                            580.125000  1121.75000
# total_goal_vmt                                         0.000000     0.00000
# ndat_rate                                             42.950000    65.10000
# goal_ndat_rate_worksite_only                           0.000000     0.00000
# total_goal_ndat_trips                                  0.000000     0.00000
# total_annual_ghg_emissions_metric_tons_C02e          185.225000   391.15000
# daily_roundtrip_ghg_per_employee_pounds                6.700000    11.00000
# ghg_for_agg_pounds                                  1126.335000  2191.48000
# total_weekly_trips                                   574.000000   904.00000
# weekly_drive_alone                                   162.250000   317.00000
# weekly_carpool                                        45.000000    85.00000
# weekly_vanpool                                         0.000000     2.00000
# weekly_1_motorcycle                                    0.000000     4.00000
# weekly_2_motorcycle                                    0.000000     0.00000
# weekly_bus                                           134.000000   286.50000
# weekly_train_lightrail_streetcar                      11.000000    28.50000
# weekly_bike                                            7.000000    18.00000
# weekly_walk                                           14.000000    34.00000
# weekly_telework                                        4.000000    15.00000
# weekly_cww                                             0.000000     1.00000
# weekly_overnight_business                              0.000000     3.00000
# weekly_did_not_work                                   10.000000    20.00000
# weekly_ferry_walk_on                                   0.000000     9.00000
# weekly_ferry_car_bus_van                               0.000000     1.00000
# weekly_other                                           4.250000    11.00000
# alone_share                                            0.200000     0.33950
# carpool_share                                          0.062000     0.08900
# van_share                                              0.000000     0.00100
# motorcycle_share                                       0.000000     0.00480
# bus_share                                              0.136000     0.32700
# train_share                                            0.013000     0.03100
# bike_share                                             0.009000     0.01800
# walk_share                                             0.018000     0.03750
# tele_share                                             0.005000     0.01500
# cww_share                                              0.000000     0.00100
# used_ferry_share                                       0.000000     0.00200
# boarded_ferry_share                                    0.000000     0.00600
# other_share                                            0.005725     0.01105
# Worksite_2017_DAR_goal                                20.000000    35.00000
# num_employees_at_worksite                            182.000000   301.00000
# How many employees arrive at your worksite betw...   127.000000   220.00000
# number_employees_using_ORCA_business_passport          0.000000   105.00000
# number_employees_using_mass_transit_subsidy            0.000000     0.00000
# number_employees_using_vanshare_carpool_subsidy        0.000000     0.00000
# number_employees_drive_alone_using_parking_subsidy     0.000000     0.00000
# number_employees_using_bike_subsidy                    0.000000     0.00000
# number_employees_using_other_transportation_sub...     0.000000     0.00000
# total_number_parking_spaces_reserved_for_employees     0.000000    20.00000
# number_reserved_HOV_parking_spaces                    -1.000000     0.00000
# number_shared_parking_spaces                          -1.000000     0.00000
# yearly_cost_promoting_CTR_and_overhead                 0.000000  1000.00000
# yearly_cost_meeting_program_requirements               0.000000   100.00000
# yearly_cost_of_financial_incentives_subsidies_t...     0.000000   115.00000
# yearly_cost_of_facilities                              0.000000     0.00000
# yearly_cost_other                                      0.000000     0.00000
#
#                                                               75%  \
# response_rate                                           83.400000
# num_employees                                          522.250000
# VMT_employee                                             9.100000
# goal_vmt                                                 0.000000
# total_vmt                                             2339.475000
# total_goal_vmt                                           0.000000
# ndat_rate                                               79.600000
# goal_ndat_rate_worksite_only                             0.000000
# total_goal_ndat_trips                                    0.000000
# total_annual_ghg_emissions_metric_tons_C02e            797.375000
# daily_roundtrip_ghg_per_employee_pounds                 17.700000
# ghg_for_agg_pounds                                    4558.380000
# total_weekly_trips                                    1568.500000
# weekly_drive_alone                                     618.500000
# weekly_carpool                                         153.750000
# weekly_vanpool                                          13.000000
# weekly_1_motorcycle                                     12.000000
# weekly_2_motorcycle                                      0.000000
# weekly_bus                                             517.000000
# weekly_train_lightrail_streetcar                        67.000000
# weekly_bike                                             43.000000
# weekly_walk                                             71.000000
# weekly_telework                                         50.000000
# weekly_cww                                               5.000000
# weekly_overnight_business                               10.000000
# weekly_did_not_work                                     41.000000
# weekly_ferry_walk_on                                    24.000000
# weekly_ferry_car_bus_van                                 6.000000
# weekly_other                                            24.000000
# alone_share                                              0.561000
# carpool_share                                            0.121000
# van_share                                                0.011000
# motorcycle_share                                         0.010500
# bus_share                                                0.493750
# train_share                                              0.056750
# bike_share                                               0.034000
# walk_share                                               0.062000
# tele_share                                               0.036000
# cww_share                                                0.004000
# used_ferry_share                                         0.009000
# boarded_ferry_share                                      0.017000
# other_share                                              0.017375
# Worksite_2017_DAR_goal                                  50.000000
# num_employees_at_worksite                              537.000000
# How many employees arrive at your worksite betw...     416.750000
# number_employees_using_ORCA_business_passport          251.000000
# number_employees_using_mass_transit_subsidy             15.000000
# number_employees_using_vanshare_carpool_subsidy          6.000000
# number_employees_drive_alone_using_parking_subsidy      34.000000
# number_employees_using_bike_subsidy                      0.000000
# number_employees_using_other_transportation_sub...       0.000000
# total_number_parking_spaces_reserved_for_employees     138.000000
# number_reserved_HOV_parking_spaces                       4.000000
# number_shared_parking_spaces                             9.000000
# yearly_cost_promoting_CTR_and_overhead                6000.000000
# yearly_cost_meeting_program_requirements              1000.000000
# yearly_cost_of_financial_incentives_subsidies_t...  121000.000000
# yearly_cost_of_facilities                              500.000000
# yearly_cost_other                                        0.000000
#
#                                                              max
# response_rate                                       1.000000e+02
# num_employees                                       2.725700e+04
# VMT_employee                                        2.210000e+01
# goal_vmt                                            1.420000e+01
# total_vmt                                           9.682280e+04
# total_goal_vmt                                      8.423600e+04
# ndat_rate                                           9.600000e+01
# goal_ndat_rate_worksite_only                        9.920000e+01
# total_goal_ndat_trips                               5.133400e+04
# total_annual_ghg_emissions_metric_tons_C02e         2.600059e+04
# daily_roundtrip_ghg_per_employee_pounds             4.360000e+01
# ghg_for_agg_pounds                                  1.921120e+05
# total_weekly_trips                                  7.274500e+04
# weekly_drive_alone                                  2.555800e+04
# weekly_carpool                                      6.540000e+03
# weekly_vanpool                                      8.490000e+02
# weekly_1_motorcycle                                 3.970000e+02
# weekly_2_motorcycle                                 4.500000e+01
# weekly_bus                                          2.643200e+04
# weekly_train_lightrail_streetcar                    2.352000e+03
# weekly_bike                                         4.979000e+03
# weekly_walk                                         2.974000e+03
# weekly_telework                                     5.310000e+03
# weekly_cww                                          6.100000e+02
# weekly_overnight_business                           1.680000e+02
# weekly_did_not_work                                 1.400000e+03
# weekly_ferry_walk_on                                7.390000e+02
# weekly_ferry_car_bus_van                            5.210000e+02
# weekly_other                                        8.860000e+02
# alone_share                                         8.800000e-01
# carpool_share                                       2.850000e-01
# van_share                                           1.960000e-01
# motorcycle_share                                    8.180000e-02
# bus_share                                           7.300000e-01
# train_share                                         3.741000e-01
# bike_share                                          2.130000e-01
# walk_share                                          1.840000e-01
# tele_share                                          4.690000e-01
# cww_share                                           1.150000e-01
# used_ferry_share                                    1.180000e-01
# boarded_ferry_share                                 1.300000e-01
# other_share                                         7.560000e-02
# Worksite_2017_DAR_goal                              1.000000e+02
# num_employees_at_worksite                           2.840800e+04
# How many employees arrive at your worksite betw...  2.150000e+04
# number_employees_using_ORCA_business_passport       4.750000e+04
# number_employees_using_mass_transit_subsidy         1.900000e+03
# number_employees_using_vanshare_carpool_subsidy     2.500000e+03
# number_employees_drive_alone_using_parking_subsidy  7.900000e+02
# number_employees_using_bike_subsidy                 7.900000e+02
# number_employees_using_other_transportation_sub...  3.685000e+03
# total_number_parking_spaces_reserved_for_employees  1.024000e+04
# number_reserved_HOV_parking_spaces                  7.010000e+02
# number_shared_parking_spaces                        1.066300e+04
# yearly_cost_promoting_CTR_and_overhead              5.000000e+06
# yearly_cost_meeting_program_requirements            5.000000e+06
# yearly_cost_of_financial_incentives_subsidies_t...  1.202780e+07
# yearly_cost_of_facilities                           1.850000e+05
# yearly_cost_other                                   2.850000e+06

# %%
len(categorical_columns), len(numerical_columns)
# Out:
# (47, 59)

# %%
# skew_values = list()
# for num_col in commute_stats_df.index:
#     num_col_skew = stats.skew(commute_df[num_col])
#     skew_values.append(num_col_skew)
# commute_stats_df['skew'] = pd.Series(skew_values)
# commute_stats_df

# # why is this useful?!

# %% [markdown]
# ## 4. Assess Nulls
#
# #### Numerical

# %%
null_numerical_cols = []
for col in numerical_columns:
    if commute_df_with_nulls[col].isnull().any():
        null_numerical_cols.append(col)
null_numerical_cols
# Out:
# ['number_employees_using_ORCA_business_passport',
#  'number_employees_using_mass_transit_subsidy',
#  'number_employees_using_vanshare_carpool_subsidy',
#  'number_employees_drive_alone_using_parking_subsidy',
#  'number_employees_using_bike_subsidy',
#  'number_employees_using_other_transportation_subsidy',
#  'yearly_cost_promoting_CTR_and_overhead',
#  'yearly_cost_meeting_program_requirements',
#  'yearly_cost_of_financial_incentives_subsidies_to_employees',
#  'yearly_cost_of_facilities',
#  'yearly_cost_other']

# %%
for col in null_numerical_cols:
    commute_df_with_nulls[col].fillna(commute_df_with_nulls[col].median(), inplace=True)

# %% [markdown]
# #### Categorical

# %%
null_cat_cols = []
for col in categorical_columns:
    if commute_df_with_nulls[col].isnull().any():
        null_cat_cols.append(col)
null_cat_cols
# Out:
# ['reason_for_moving',
#  'familiar_with_TMP',
#  'visible_ETC_info',
#  'provides_commute_info_via_digital_visible_display',
#  'time_last_distributed_commute_info',
#  'Do you distribute\xa0transportation program information to new hires via a new employee orientation/hiring packet/new hire online modules?',
#  'bus_streetcar_within_3_blocks',
#  'light_rail_train_within_3_blocks',
#  'bike_ped_trail_within_3_blocks',
#  'sidewalks',
#  'ORCA_business_passport_offfered',
#  'offers_mass_transit_benefit_subsidy_other_than_ORCA_business',
#  'offers_vanshare_carpool_subsidy',
#  'offers_parking_subsidy_for_vanshares-carpools',
#  'offers_parking_subsidy_for_drive_alone',
#  'offers_bike_subsidy',
#  'offers_other_non-specific_transportation_subsidy',
#  'Please\xa0enter\xa0any details about subsidies',
#  'offers_showers_for_walkers_bicyclists',
#  'offers_lockers_for_walkers_bicyclists',
#  'offers_locked_bike_room_for_walkers_bicyclists',
#  'offers_covered_racks_for_walkers_bicyclists',
#  'offers_uncovered_racks_for_walkers_bicyclists',
#  'employees_able_to_set_aside_pretax_income_for_transit_vanpool_cost',
#  'offers_remove_work_options',
#  'offers_flexible_work_hours',
#  'offers_compressed_work_week_scheduling',
#  'offers_free_ride_home_in_emergency',
#  'offers_carshare_discounts',
#  'offers_lyft_uber_taxi_discounts',
#  'offers_bikeshare_discounts',
#  'employer_provided_shuttle_available',
#  'internal_circulator_available',
#  'employer_provided_cars_for_offsite_business_appointments_available',
#  'offers_company_provided_bikes',
#  'offers_internal_carpool_ride_matching',
#  'offers_rideshare_online_3rdparty_ride_matching',
#  'additional_transportation_benefits',
#  'explanation_of_other_cost',
#  'employer_applied_for_state_tax_credits_for_supporting_employee_commute_alternatives',
#  "What are your worksite's\xa0transportation program priorities for the next 6 months?1",
#  "What are your worksite's\xa0transportation program priorities for the next 6 months?2",
#  "What are your worksite's\xa0transportation program priorities for the next 6 months?3"]

# %%
for col in null_cat_cols:
    commute_df_with_nulls[col] = commute_df_with_nulls[col].astype(object)

# %%
commute_df_with_nulls.offers_bike_subsidy.dtypes
# Out:
# dtype('O')

# %%
for col in null_cat_cols:
    commute_df_with_nulls[col] = commute_df_with_nulls[col].fillna('NA')

# %%
for col in null_cat_cols:
    commute_df_with_nulls[col] = commute_df_with_nulls[col].astype('category')

# %%
commute_df_with_nulls.isnull().any().any()
# Out:
# False

# %% [markdown]
# ## 5. Other random cleaning issues
#
# #### In these two columns, a goal is noted in the first entry for the worksite but doesn't carry over to each subsequant year.

# %%
wacky_columns = ['goal_vmt', 'goal_ndat_rate_worksite_only']

# %%
max_val_vmt = commute_df_with_nulls.groupby('UUID')['goal_vmt'].max()
max_val_ndat = commute_df_with_nulls.groupby('UUID')['goal_ndat_rate_worksite_only'].max()

# %%
commute_df_with_nulls['goal_vmt'] = commute_df_with_nulls['UUID'].apply(lambda x: max_val_vmt.loc[x])

# %%
commute_df_with_nulls['goal_ndat_rate_worksite_only'] = commute_df_with_nulls['UUID'].apply(lambda x: max_val_ndat.loc[x])

# %% [markdown]
# ## DataFrames to Pickle

# %%
commute_df_with_nulls.to_pickle('./data/no_null_commute_df.pkl')

# %%
clean_commute_stats_df = commute_df_with_nulls.describe().T

# %%
clean_commute_stats_df.to_pickle('./data/clean_commute_stats_df.pkl')

# %%
clean_commute_dtypes_df = pd.DataFrame([commute_df_with_nulls.dtypes],
                                 index=['column_dtypes']).T
clean_commute_dtypes_df.to_pickle('./data/commute_dtypes')
